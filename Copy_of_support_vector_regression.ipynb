# %% [markdown]
# <a href="https://colab.research.google.com/github/nordak005/machine_Learning_codes/blob/main/Copy_of_support_vector_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Support Vector Regression (SVR)

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
data=pd.read_csv('/Position_Salaries.csv')
X=data.iloc[:,1:-1].values
y=data.iloc[:,-1].values

# %% [markdown]
# ## Feature Scaling

# %%
print(y)
# Out:
# [[-0.72004253]
#  [-0.70243757]
#  [-0.66722767]
#  [-0.59680786]
#  [-0.49117815]
#  [-0.35033854]
#  [-0.17428902]
#  [ 0.17781001]
#  [ 0.88200808]
#  [ 2.64250325]]

# %%
 y=y.reshape(len(y),1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
sc_y=StandardScaler()
X=sc_X.fit_transform(X)
y=sc_y.fit_transform(y)

# %% [markdown]
# ## Training the SVR model on the whole dataset

# %%
from sklearn.svm import SVR
r=SVR(kernel='rbf')
r.fit(X,y)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %% [markdown]
# ## Predicting a new result

# %%
sc_y.inverse_transform(r.predict(sc_X.transform([[6.5]])).reshape(-1,1))
# Out:
# array([[252789.13921624]])

# %% [markdown]
# ## Visualising the SVR results

# %%
plt.scatter(sc_X.inverse_transform(X),sc_y.inverse_transform(y),color='red')
plt.plot(sc_X.inverse_transform(X),sc_y.insverse_transform(r.predict(X).reshape(-1,1)),color='blue)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_681/2213929246.py in <cell line: 0>()
#       1 plt.scatter(sc_X.inverse_transform(X),sc_y.inverse_transform(y),color='red')
# ----> 2 plt.plot(sc_X.inverse_transform(X),sc_y.insverse_transform(r.predict(X).reshape(-1,1)),color='blue)')
#
# AttributeError: 'StandardScaler' object has no attribute 'insverse_transform'

# %% [markdown]
# ## Visualising the SVR results (for higher resolution and smoother curve)
